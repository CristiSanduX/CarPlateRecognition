# %% [markdown]
# <a href="https://colab.research.google.com/github/CristiSanduX/CarPlateRecognition/blob/main/P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x  = [1, 2, 3, 4, 5, 6, 7, 8, 9]
y1 = [1, 3, 5, 3, 1, 3, 5, 3, 1]
y2 = [2, 4, 6, 4, 2, 4, 6, 4, 2]

plt.plot(x, y1, label="Linia L", color="blue")
plt.plot(x, y2, label="Linia H", color="red")

plt.xlabel("AXA X")
plt.ylabel("AXA Y")
plt.title("PIM - CSX-SA07")
plt.legend()
plt.show()
